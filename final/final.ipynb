# %% [markdown]
# ## Introduction
# Diabetes is considered as one of the most critical issues in recent days due to an increased number of diabetes among the people. This has been illustrated as diabetes has been observed to be increased by almost 34% in 2021 in comparison to 2015 due to which the mortality rate of the people is also increasing all across the globe. It is also identified that the diabetic condition is there among 422 million people all across the globe where the majority of the people are observed to be having low and middle countries.
# On the other hand 1.5 million people are observed to die due to the diabetic condition each year. In this context diabetes issues are also observed with creating risk of early death and other complications that can lower the quality of life (Who.int, 2022). High global burden of diabetes is also having a negative economic impact on the healthcare system as well as individuals. In this regard it has become essential to credit the occurrence of diabetes among the patient so that it can be treated in an early stage and the issue can be prevented in an effective and advanced manner. For the purpose of incorporating the prediction model machine learning technique has been considered as one of the most important and effective techniques for the purpose of developing the model which is going to be done in the concerned assessment along with proper maintenance of all the factors associated with it.

# %% [markdown]
# ## Literature review
# It is identified that the diabetes issue is becoming a global issue as it has been observed to be creating a risk of early death as well as complications among the lifestyle. In this context the diabetes issue has been observed to be estimated to be more than 366 million by 2013 which was 171 million diabetic conditions among people in 2020 (who.int, 2022). How you for that diabetic conditions are also observed to be majorly among the low and middle income countries which is negatively impacting the modulated rate of the countries as well. In this context the diabetic condition needs to be tackled appropriately with the help of effective techniques so that the problem can be resolved as well as the situation can be overcome. The diabetic condition needs to be tackled for the purpose of minimizing serious health problems such as vision loss, kidney disease and heart disease. In this context the consumer assessment is going to demonstrate the usage of machine learning techniques for the purpose of developing a technique which can be useful to analyze the factors that are observed to be creating the diabetic issue among people (Kaur and Kumari, 2020). In this context it can be helpful for the purpose of enhancing the situation among Health care organizations for the purpose of analyzing the factors which are negatively impacting people towards becoming diabetic.

# %%
## For the purpose of analyzing the diabetic condition, importing the essential libraries has been observed to be done so that the datasheet can be used for the purpose of analyzing the diabetic conditionamong people 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
sns.set_style('whitegrid')

# %%
## the below step demonstrates the importing of data sets  for the purpose of using the data sets to analyze the factors that create high risk of diabetes among people

dataframe = pd.read_csv('diabetes2.csv') 
dataframe1 = pd.read_csv('Medicalpremium.csv')

# %%
dataframe.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataframe1.head(5)
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %% [markdown]
# #### The above- mentioned tables can be seen to be clearly displaying the details of data one, including information about glucose levels, blood pressure, skin thickness, insulin levels, BMI rates, and the functions and outcomes of diabetes prediction as one and zero. In accordance with the values of all the attributes, one represents the prevalence of diabetes, and zero represents a non-diabetic condition among people. The other data set has been seen to include details about diabetes, blood pressure issues, any visible height, weight, and allergies, as well as any history of other diseases in the family. These two data sets will be combined and used in the upcoming investigation.

# %%
dataframe2 = pd.merge(dataframe1, dataframe)

# %%
## The below mentioned table demonstrates the merging of two data sets that is going to be used for the research.
dataframe2.head(5)
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   45         0                      0               0                   0
# 2   45         0                      0               0                   0
# 3   45         0                      0               0                   0
# 4   45         0                      0               0                   0
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     155      57               0                        0
# 2     155      57               0                        0
# 3     155      57               0                        0
# 4     155      57               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice  Pregnancies  Glucose  BloodPressure  \
# ...

# %%
dataframe2.shape
# Out:
# (15353, 19)

# %%
dataframe2.duplicated().sum()
# Out:
# 0

# %%
dataframe2.isnull().sum()
# Out:
# Age                         0
# Diabetes                    0
# BloodPressureProblems       0
# AnyTransplants              0
# AnyChronicDiseases          0
# Height                      0
# Weight                      0
# KnownAllergies              0
# HistoryOfCancerInFamily     0
# NumberOfMajorSurgeries      0
# PremiumPrice                0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Outcome                     0
# dtype: int64

# %%
dataframe2.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice',
#        'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Outcome'],
#       dtype='object')

# %%
## The below mentioned table has been observed to be demonstrating the aggregation of the data with the help of using the above formula in which the sum has been observed to be zero and maximum value is one.
dataframe2.aggregate({"Diabetes":['sum', 'min', 'max']})
# Out:
#      Diabetes
# sum      5647
# min         0
# max         1

# %%
## The above figure demonstrates the data aggregation of glucose in which the sum has been observed to be 185 + 685 minimum value is zero and maximum value is 199.
dataframe2.aggregate({"Glucose":['sum', 'min','max']})
# Out:
#      Glucose
# sum  1852685
# min        0
# max      199

# %%
## The below mwntioned table aggregate of blood pressure of the value is 1064078 minimum value is zero and maximum value is 122.
dataframe2.aggregate({"BloodPressure":['sum', 'min','max']})
# Out:
#      BloodPressure
# sum        1064076
# min              0
# max            122

# %%
dataframe2[dataframe2.BloodPressureProblems==0].value_counts().sum()
# Out:
# 8960

# %%
dataframe2['BMI'].mean()
# Out:
# 32.10921643978376

# %%
dataframe2.describe()
# Out:
#                 Age      Diabetes  BloodPressureProblems  AnyTransplants  \
# count  15353.000000  15353.000000           15353.000000    15353.000000
# mean      32.898912      0.367811               0.416401        0.065915
# std       10.956892      0.482225               0.492978        0.248142
# min       21.000000      0.000000               0.000000        0.000000
# 25%       24.000000      0.000000               0.000000        0.000000
# 50%       29.000000      0.000000               0.000000        0.000000
# 75%       41.000000      1.000000               1.000000        0.000000
# max       66.000000      1.000000               1.000000        1.000000
#
#        AnyChronicDiseases        Height        Weight  KnownAllergies  \
# count        15353.000000  15353.000000  15353.000000    15353.000000
# mean             0.167589    167.999414     77.668469        0.216440
# std              0.373513     10.314211     14.096977        0.411831
# ...

# %%
dataframe2[dataframe2.Diabetes==0].value_counts().sum()
# Out:
# 9706

# %%
## The below mwntioned table  demonstrates the data transformation in which the age of both the data sets have been observed to be transformed together in order to get a sum value.
dataframe2.groupby('Age')['Age'].transform('sum')
# Out:
# 0        16875
# 1        16875
# 2        16875
# 3        16875
# 4        16875
#          ...
# 15348     3315
# 15349     3315
# 15350     3315
# 15351     3315
# 15352     3315
# Name: Age, Length: 15353, dtype: int64

# %%
## The below mentioned table  demonstrates a second transformation of the data in which the height of both the data sets has been observed to be included together to get a sum value.
dataframe2.groupby('Height')['Height'].transform('sum')
# Out:
# 0         25575
# 1         25575
# 2         25575
# 3         25575
# 4         25575
#           ...
# 15348     55774
# 15349     55774
# 15350    132302
# 15351    132302
# 15352    132302
# Name: Height, Length: 15353, dtype: int64

# %%
## The below mentioned table has been observed to be demonstrating the data transmission in which the weight of the column has been observed to be used for the purpose of getting a group that can provide an added value
dataframe2.groupby('Weight')['Weight'].transform('sum')
# Out:
# 0        26334
# 1        26334
# 2        26334
# 3        26334
# 4        26334
#          ...
# 15348    26975
# 15349    26975
# 15350    39493
# 15351    39493
# 15352    39493
# Name: Weight, Length: 15353, dtype: int64

# %%
## The above figure demonstrates the transformation of data in which the premium price is grouped by.
dataframe2.groupby('PremiumPrice')['PremiumPrice'].transform('sum')
# Out:
# 0        20000000
# 1        20000000
# 2        20000000
# 3        20000000
# 4        20000000
#            ...
# 15348    10208000
# 15349    10208000
# 15350     7000000
# 15351     7000000
# 15352     7000000
# Name: PremiumPrice, Length: 15353, dtype: int64

# %%
## below mentioned table Demonstrate the data transmission of outcome in which the aggregate value is demonstrated.
dataframe2.groupby('Outcome')['Outcome'].transform('sum')
# Out:
# 0           0
# 1           0
# 2           0
# 3        5521
# 4        5521
#          ...
# 15348       0
# 15349       0
# 15350       0
# 15351       0
# 15352       0
# Name: Outcome, Length: 15353, dtype: int64

# %%
x = dataframe2['Age']

y = dataframe2['BloodPressure']
  

fig = plt.figure(figsize = (10, 5))
 

plt.bar(x, y, color ='green',
        width = 0.4)
 
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.title("Age vs Blood Pressure")
plt.show()

# %% [markdown]
# ##### Data visualization of age versus blood pressure and it has been represented with the help of bar blot. It has been identified that with the increased age the blood pressure of people is observed to be increased in most cases that has been observed to be negatively impacting the occurrence of diabetes among people.

# %%
plt.hist(dataframe2['Glucose'], 20,
         density=True,
         histtype='bar',
         facecolor='b',
         alpha=0.5)

plt.show()

# %% [markdown]
# #### Histogram of ‘Glucose’ column.Demonstrates the histogram of glucose in which the value has been observed to be increased with the increased age and it negatively impacts the occurrence of diabetic issue.

# %%
plt.hist(dataframe2['Insulin'], 20,
         density=True,
         histtype='bar',
         facecolor='b',
         alpha=0.5)

plt.show()

# %% [markdown]
# #### Histogram of ‘Insulin’ column. The above figure has been observed to be demonstrating the histogram of the insulin column in which the valley has been observed to be increased for diabetic issue people that means the insulin has a positive impact on occurrence of diabetes.

# %%
plt.hist(dataframe2['BMI'], 20,
         density=True,
         histtype='bar',
         facecolor='b',
         alpha=0.5)

plt.show()

# %% [markdown]
# #### Histogram of ‘BMI’ column. Histogram of BMI rate demonstrates that with increased BMI rate the diabetic shoe also increases.

# %%
for i in dataframe2.columns:
    if(i != 'Outcome'):
        plt.figure(figsize = (14,4))
        plt.subplot(1,2,1)
        sns.histplot(x =dataframe2[i], hue = dataframe2['Outcome'])
        plt.title(i)
    
        plt.subplot(1,2,2)
       
        stats.probplot(x =dataframe2[i], dist ='norm', plot = plt)               
    plt.show()

# %% [markdown]
# #### Conclusion
# Based on the discussions made in the section it can be demonstrated that diabetic all across the globe due to which there is of early death has been observed to be found among people which has also been observed with creating increased mortality rate all across the globe. In this context the condition can be mitigated with the help of a predictive model that has been created with the help of machine learning techniques. In this context the machine learning technique has involved two data sets that contain several values of glucose BMI rate and others. This can be used for the purpose of preventing the diabetes issue among people.
